# %%
import numpy as np
import h5py
import os, sys
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import image as mpimg
import yaml
import argparse
import itertools

sys.path.append('../')
import utils
import settings
plt.style.use('../spectrum.mplstyle')
sys.path.append('../spectrums')
import compare_spectrums

# %%
f = plt.figure()
f.set_figwidth(8)
f.set_figheight(8)
plt.subplot(2,1,1)
compare_spectrums.compare_spectrums()
plt.subplot(2,1,2)
plt.plot([0,1,2],[0,1,4])
f.align_ylabels()
plt.tight_layout()
plt.savefig("G1u0.pdf")
# Out:
# Duplicate Values: PSQ0, G1u, pi(0)S(0)_ref
# Duplicate Values: PSQ0, G1u, pi(1)S(1)_ref
# Duplicate Values: PSQ0, G1u, k(1)N(1)_ref
# Duplicate Values: PSQ0, G1g, pi(1)S(1)_ref
# Duplicate Values: PSQ1, G1, pi(0)S(1)_ref
# Duplicate Values: PSQ1, G1, k(1)N(0)_ref
# Duplicate Values: PSQ1, G2, pi(1)S(2)_ref
# Duplicate Values: PSQ1, G2, k(1)N(2)_ref
# Duplicate Values: PSQ2, G, pi(0)S(2)_ref
# Duplicate Values: PSQ2, G, pi(1)S(1)_ref
# Duplicate Values: PSQ2, G, k(0)N(2)_ref
# Duplicate Values: PSQ2, G, k(2)N(0)_ref
# Duplicate Values: PSQ3, G, pi(0)S(3)_ref
# Duplicate Values: PSQ3, G, k(0)N(3)_ref
# Duplicate Values: PSQ3, G, k(3)N(0)_ref
# Duplicate Values: PSQ0, G1u, pi(0)S(0)_ref
# Duplicate Values: PSQ0, G1u, pi(1)S(1)_ref
# Duplicate Values: PSQ0, G1u, k(1)N(1)_ref
# Duplicate Values: PSQ0, G1g, pi(1)S(1)_ref
# Duplicate Values: PSQ0, Hu, k(1)N(1)_ref
# Duplicate Values: PSQ1, G1, pi(0)S(1)_ref
# Duplicate Values: PSQ1, G1, pi(1)S(0)_ref
# Duplicate Values: PSQ1, G1, k(1)N(0)_ref
# Duplicate Values: PSQ1, G2, pi(1)S(2)_ref
# Duplicate Values: PSQ1, G2, k(1)N(2)_ref
# Duplicate Values: PSQ2, G, pi(0)S(2)_ref
# Duplicate Values: PSQ2, G, pi(1)S(1)_ref
# Duplicate Values: PSQ2, G, pi(2)S(0)_ref
# Duplicate Values: PSQ2, G, k(0)N(2)_ref
# Duplicate Values: PSQ2, G, k(2)N(0)_ref
# Duplicate Values: PSQ3, F1, pi(2)S(1)_ref
# Duplicate Values: PSQ3, F2, k(2)N(1)_ref
# Duplicate Values: PSQ3, G, pi(0)S(3)_ref
# Duplicate Values: PSQ3, G, k(0)N(3)_ref
# Duplicate Values: PSQ3, G, k(3)N(0)_ref
# Duplicate Values: PSQ0, G1u, pi(0)S(0)_ref
# Duplicate Values: PSQ0, G1u, pi(1)S(1)_ref
# Duplicate Values: PSQ0, G1u, k(1)N(1)_ref
# Duplicate Values: PSQ0, G1g, pi(1)S(1)_ref
# Duplicate Values: PSQ0, Hu, k(1)N(1)_ref
# Duplicate Values: PSQ1, G1, pi(0)S(1)_ref
# Duplicate Values: PSQ1, G1, pi(1)S(0)_ref
# Duplicate Values: PSQ1, G1, k(1)N(0)_ref
# Duplicate Values: PSQ1, G2, pi(1)S(2)_ref
# Duplicate Values: PSQ1, G2, k(1)N(2)_ref
# Duplicate Values: PSQ2, G, pi(0)S(2)_ref
# Duplicate Values: PSQ2, G, pi(1)S(1)_ref
# Duplicate Values: PSQ2, G, pi(2)S(0)_ref
# Duplicate Values: PSQ2, G, k(0)N(2)_ref
# Duplicate Values: PSQ2, G, k(2)N(0)_ref
# Duplicate Values: PSQ3, F1, pi(2)S(1)_ref
# Duplicate Values: PSQ3, F2, k(2)N(1)_ref
# Duplicate Values: PSQ3, G, pi(0)S(3)_ref
# Duplicate Values: PSQ3, G, k(0)N(3)_ref
# Duplicate Values: PSQ3, G, k(3)N(0)_ref
# Duplicate Values: PSQ0, G1u, pi(0)S(0)_ref
# Duplicate Values: PSQ0, G1u, pi(1)S(1)_ref
# Duplicate Values: PSQ0, G1u, k(1)N(1)_ref
# Duplicate Values: PSQ0, G1g, pi(1)S(1)_ref
# Duplicate Values: PSQ0, Hu, k(1)N(1)_ref
# Duplicate Values: PSQ1, G1, pi(0)S(1)_ref
# Duplicate Values: PSQ1, G1, pi(1)S(0)_ref
# Duplicate Values: PSQ1, G1, k(1)N(0)_ref
# Duplicate Values: PSQ1, G2, pi(1)S(2)_ref
# Duplicate Values: PSQ1, G2, k(1)N(2)_ref
# Duplicate Values: PSQ2, G, pi(0)S(2)_ref
# Duplicate Values: PSQ2, G, pi(1)S(1)_ref
# Duplicate Values: PSQ2, G, pi(2)S(0)_ref
# Duplicate Values: PSQ2, G, k(0)N(2)_ref
# Duplicate Values: PSQ2, G, k(2)N(0)_ref
# Duplicate Values: PSQ3, F1, pi(2)S(1)_ref
# Duplicate Values: PSQ3, F2, k(2)N(1)_ref
# Duplicate Values: PSQ3, G, pi(0)S(3)_ref
# Duplicate Values: PSQ3, G, k(0)N(3)_ref
# Duplicate Values: PSQ3, G, k(3)N(0)_ref
# Old xrange: (-0.7, 0.705)
# New xrange: (-0.3, 0.705)

# %%
def test_plot():
#     f=plt.figure()
#     f.set_figwidth(4)
#     f.set_figheight(8)
    plt.plot([1,2,3],[1,4,9])

# %%
plt.subplot(2,1,1)
test_plot()
plt.subplot(2,1,2)
test_plot()
